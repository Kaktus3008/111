# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaktus3008/111/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%94%D0%BE%D0%B1%D1%80%D0%BE_%D0%BF%D0%BE%D0%B6%D0%B0%D0%BB%D0%BE%D0%B2%D0%B0%D1%82%D1%8C_%D0%B2_Colaboratory!%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})

# %%
df1 = pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})

# %%
df2 = pd.DataFrame({'x':[3,1,2], 'y':[0,2,2]})

# %%
print (df1>=df2)
# Out:
#        x      y
# 0  False   True
# 1   True   True
# 2   True  False

# %%
data = {'Имя': ['Анна', 'Борис', None, 'Джон'],
 'Возраст': [25, 30, 28, None]}
df = pd.DataFrame(data)

# %%
df
# Out:
#      Имя  Возраст
# 0   Анна     25.0
# 1  Борис     30.0
# 2   None     28.0
# 3   Джон      NaN

# %%
df.isnull()
# Out:
#      Имя  Возраст
# 0  False    False
# 1  False    False
# 2   True    False
# 3  False     True

# %%
x=df.isnull()
df.isnull().loc[x["Имя"] == True]
# Out:
#     Имя  Возраст
# 2  True    False
