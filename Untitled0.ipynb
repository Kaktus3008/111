# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaktus3008/111/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Загрузка библиотеки Pandas

# %%
import pandas as pd

# %% [markdown]
# Создание дата фрейма из файла "Amazon_popular_books_dataset.csv"

# %%
data=pd.read_csv("Amazon_popular_books_dataset.csv")

# %% [markdown]
# Вывод информации о содержимом дата фрейма

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2269 entries, 0 to 2268
# Data columns (total 40 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   asin                  2269 non-null   object
#  1   ISBN10                1429 non-null   object
#  2   answered_questions    2269 non-null   int64
#  3   availability          1375 non-null   object
#  4   brand                 2268 non-null   object
#  5   currency              2269 non-null   object
#  6   date_first_available  3 non-null      object
#  7   delivery              2269 non-null   object
#  8   department            0 non-null      float64
#  9   description           712 non-null    object
#  10  discount              1177 non-null   float64
#  11  domain                2269 non-null   object
#  12  features              2269 non-null   object
#  13  final_price           1392 non-null   float64
#  14  format                2173 non-null   object
# ...

# %% [markdown]
# Поиск пропущенных значений

# %%
data.isnull()
# Out:
#        asin  ISBN10  answered_questions  availability  brand  currency  \
# 0     False   False               False         False  False     False
# 1     False   False               False         False  False     False
# 2     False   False               False          True  False     False
# 3     False   False               False         False  False     False
# 4     False   False               False         False  False     False
# ...     ...     ...                 ...           ...    ...       ...
# 2264  False    True               False          True  False     False
# 2265  False    True               False          True  False     False
# 2266  False    True               False          True  False     False
# 2267  False    True               False          True  False     False
# 2268  False    True               False          True  False     False
#
#       date_first_available  delivery  department  description  ...   upc  \
# ...

# %% [markdown]
# Вывод пропущенных строк в столбце "discount"

# %%
data.isnull().loc[data["discount"] == True]
# Out:
#        asin  ISBN10  answered_questions  availability  brand  currency  \
# 49    False   False               False         False  False     False
# 245   False   False               False         False  False     False
# 249   False   False               False         False  False     False
# 406   False   False               False         False  False     False
# 589   False   False               False         False  False     False
# 622   False   False               False         False  False     False
# 770   False   False               False         False  False     False
# 1072  False   False               False         False  False     False
# 1111  False   False               False         False  False     False
# 1117  False   False               False         False  False     False
# 1361  False   False               False         False  False     False
# 1618  False    True               False         False  False     False
#
# ...

# %% [markdown]
# Рассчет корреляции между всеми данными дата фрейма

# %%
data.corr()
# Out:
# <ipython-input-13-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                     answered_questions  department  discount  final_price  \
# answered_questions            1.000000         NaN -0.012606     0.019299
# department                         NaN         NaN       NaN          NaN
# discount                     -0.012606         NaN  1.000000     0.344244
# final_price                   0.019299         NaN  0.344244     1.000000
# images_count                  0.049576         NaN -0.024141    -0.071282
# initial_price                -0.018751         NaN  0.844913     0.766232
# plus_content                       NaN         NaN       NaN          NaN
# reviews_count                -0.002875         NaN  0.071574     0.088680
# ...
